# %%
import cv2
import os
import shutil
import itertools

# %%
from skimage.io import imread_collection
import glob
#your path 
yes_dir = glob.glob('C:/git/obrazyMRI/data/brain_tumor_dataset/yes/*')
no_dir =glob.glob('C:/git/obrazyMRI/data/brain_tumor_dataset/no/*')

# %%
len(yes_dir + no_dir)
# Out:
# 253

# %%
IMG_yes=imread_collection(yes_dir[0:3])

# %%
import matplotlib.pyplot as plt
for i in IMG_yes:
    plt.imshow(i)
    plt.show()

# %%
IMG_no=imread_collection(no_dir[0:3])

# %%
for i in IMG_no:
    plt.imshow(i)
    plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(3):
    plt.subplot(5,5,i+1)
    plt.imshow(IMG_no[i])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(IMG_no[i], cmap=plt.cm.binary)
plt.show()

# %%
IMG_no[0].shape
# Out:
# (630, 630)

# %%
IMG_no[1].shape
# Out:
# (200, 200, 3)

# %%
IMG_no[2].shape
# Out:
# (630, 630, 3)

# %%
plt.imshow(IMG_no[0])
plt.colorbar()

# %%
plt.imshow(IMG_no[2])
plt.colorbar()

# %%
type(IMG_no)
# Out:
# skimage.io.collection.ImageCollection

# %%
import os

# define the name of the directory to be created
path = ["C:/git/obrazyMRI/data/TEST/YES","C:/git/obrazyMRI/data/TEST/NO", "C:/git/obrazyMRI/data/TRAIN/YES",
       "C:/git/obrazyMRI/data/TRAIN/NO", "C:/git/obrazyMRI/data/VAL/YES", "C:/git/obrazyMRI/data/VAL/NO"]
for i in path:
    try:
        os.makedirs(i)
    except OSError:
        print ("Creation of the directory %s failed" % i)
    else:
        print ("Successfully created the directory %s" % i)
# Out:
# Creation of the directory C:/git/obrazyMRI/data/TEST/YES failed
# Creation of the directory C:/git/obrazyMRI/data/TEST/NO failed
# Creation of the directory C:/git/obrazyMRI/data/TRAIN/YES failed
# Creation of the directory C:/git/obrazyMRI/data/TRAIN/NO failed
# Creation of the directory C:/git/obrazyMRI/data/VAL/YES failed
# Creation of the directory C:/git/obrazyMRI/data/VAL/NO failed

# %%
from math import *
import numpy as np
yes_test=np.random.choice(yes_dir, size=5, replace=False)
for i in yes_test:
    shutil.copy(i, "C:/git/obrazyMRI/data/TEST/YES" )
yes_dir=list(set(yes_dir)-set(yes_test))
yes_train=np.random.choice(yes_dir, size=floor(0.8*len(yes_dir)), replace=False)
for i in yes_train:
    shutil.copy(i, "C:/git/obrazyMRI/data/TRAIN/YES" )
yes_val=list(set(yes_dir)-set(yes_train))
for i in yes_val:
    shutil.copy(i, "C:/git/obrazyMRI/data/VAL/YES" )

# %%
from math import *
no_test=np.random.choice(no_dir, size=5, replace=False)
for i in no_test:
    shutil.copy(i, "C:/git/obrazyMRI/data/TEST/NO" )
no_dir=list(set(no_dir)-set(no_test))
no_train=np.random.choice(no_dir, size=floor(0.8*len(no_dir)), replace=False)
for i in no_train:
    shutil.copy(i, "C:/git/obrazyMRI/data/TRAIN/NO" )
no_val=list(set(no_dir)-set(no_train))
for i in no_val:
    shutil.copy(i, "C:/git/obrazyMRI/data/VAL/NO" )

# %%
len(list(yes_test) + list(no_test))
# Out:
# 10

# %%
len(list(yes_train) + list(no_train))
# Out:
# 194

# %%
len(list(yes_val) + list(no_val))
# Out:
# 49

# %%
len(list(yes_test))
# Out:
# 5

# %%
len(list(no_test))
# Out:
# 5

# %%
len(list(yes_train))
# Out:
# 120

# %%
len(list(no_train))
# Out:
# 74

# %%
len(list(yes_val))
# Out:
# 30

# %%
len(list(no_val))
# Out:
# 19
